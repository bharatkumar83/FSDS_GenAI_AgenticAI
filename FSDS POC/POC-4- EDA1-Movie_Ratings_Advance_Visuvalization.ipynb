# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91849\\FSDS\\FSDS gen ai CW'

# %%
Movies= pd.read_csv(r"C:\Users\91849\Downloads\Movie-Rating.csv")

# %%
Movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(Movies)
# Out:
# 559

# %%
Movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
Movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
Movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
Movies.columns=['Film', 'Genre', 'Critical_Ratings', 'Audience_Ratings', 'Budget', 'Year']

# %%
Movies.head()
# Out:
#                     Film      Genre  Critical_Ratings  Audience_Ratings  \
# 0  (500) Days of Summer      Comedy                87                81
# 1            10,000 B.C.  Adventure                 9                44
# 2             12 Rounds      Action                30                52
# 3              127 Hours  Adventure                93                84
# 4              17 Again      Comedy                55                70
#
#    Budget  Year
# 0       8  2009
# 1     105  2008
# 2      20  2009
# 3      18  2010
# 4      20  2009

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    object
#  1   Genre             559 non-null    object
#  2   Critical_Ratings  559 non-null    int64
#  3   Audience_Ratings  559 non-null    int64
#  4   Budget            559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
Movies.describe()
# Out:
#        Critical_Ratings  Audience_Ratings      Budget         Year
# count        559.000000        559.000000  559.000000   559.000000
# mean          47.309481         58.744186   50.236136  2009.152057
# std           26.413091         16.826887   48.731817     1.362632
# min            0.000000          0.000000    0.000000  2007.000000
# 25%           25.000000         47.000000   20.000000  2008.000000
# 50%           46.000000         58.000000   35.000000  2009.000000
# 75%           70.000000         72.000000   65.000000  2010.000000
# max           97.000000         96.000000  300.000000  2011.000000

# %%
Movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
Movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
Movies.Film= Movies.Film.astype('category')

# %%
Movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
Movies.head()
# Out:
#                     Film      Genre  Critical_Ratings  Audience_Ratings  \
# 0  (500) Days of Summer      Comedy                87                81
# 1            10,000 B.C.  Adventure                 9                44
# 2             12 Rounds      Action                30                52
# 3              127 Hours  Adventure                93                84
# 4              17 Again      Comedy                55                70
#
#    Budget  Year
# 0       8  2009
# 1     105  2008
# 2      20  2009
# 3      18  2010
# 4      20  2009

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    object
#  2   Critical_Ratings  559 non-null    int64
#  3   Audience_Ratings  559 non-null    int64
#  4   Budget            559 non-null    int64
#  5   Year              559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
Movies.Genre= Movies.Genre.astype('category')
Movies.Year= Movies.Year.astype('category')

# %%
Movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
Movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Film              559 non-null    category
#  1   Genre             559 non-null    category
#  2   Critical_Ratings  559 non-null    int64
#  3   Audience_Ratings  559 non-null    int64
#  4   Budget            559 non-null    int64
#  5   Year              559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
Movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
Movies.describe()
# Out:
#        Critical_Ratings  Audience_Ratings      Budget
# count        559.000000        559.000000  559.000000
# mean          47.309481         58.744186   50.236136
# std           26.413091         16.826887   48.731817
# min            0.000000          0.000000    0.000000
# 25%           25.000000         47.000000   20.000000
# 50%           46.000000         58.000000   35.000000
# 75%           70.000000         72.000000   65.000000
# max           97.000000         96.000000  300.000000

# %%
from matplotlib import pyplot as  plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = Movies, x = 'Critical_Ratings', y = 'Audience_Ratings')

# %%
j = sns.jointplot( data = Movies, x = 'Critical_Ratings', y = 'Audience_Ratings', kind='hex')

# %%
j = sns.jointplot( data = Movies, x = 'Critical_Ratings', y = 'Audience_Ratings', kind='reg')

# %%
m1 = sns.distplot(Movies.Audience_Ratings)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(Movies.Audience_Ratings, bins =15)

# %%
n1= plt.hist(Movies.Audience_Ratings,bins=15)

# %%
sns.set_style('white')

# %%
n1= plt.hist(Movies.Audience_Ratings, bins=20)

# %%
n2= plt.hist(Movies.Critical_Ratings,bins=20)

# %%
 h1= plt.hist(Movies.Budget)

# %%
plt.hist(Movies[Movies.Genre=='Drama'].Budget)
plt.xlabel('Budget of Drama movies')
plt.ylabel('No. of movies')
plt.show()

# %%
Movies.head()
# Out:
#                     Film      Genre  Critical_Ratings  Audience_Ratings  \
# 0  (500) Days of Summer      Comedy                87                81
# 1            10,000 B.C.  Adventure                 9                44
# 2             12 Rounds      Action                30                52
# 3              127 Hours  Adventure                93                84
# 4              17 Again      Comedy                55                70
#
#    Budget  Year
# 0       8  2009
# 1     105  2008
# 2      20  2009
# 3      18  2010
# 4      20  2009

# %%
Movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
# stacked histograms- means the histograms which are overlapped each other

plt.hist(Movies[Movies.Genre=="Action"].Budget,bins=20)
plt.hist(Movies[Movies.Genre=="Adventure"].Budget,bins=20)
plt.hist(Movies[Movies.Genre=='Drama'].Budget,bins=20)
plt.legend(Movies.Genre)
plt.show()

# %%
plt.hist([Movies[Movies.Genre=="Action"].Budget,\
          Movies[Movies.Genre=="Drama"].Budget,\
          Movies[Movies.Genre=="Adventure"].Budget,\
          Movies[Movies.Genre=="Thriller"].Budget],
          bins=20,stacked=True)
plt.legend(Movies.Genre)
plt.show()

# %%
for gen in Movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
# visualizing using seaborn

vis1= sns.lmplot(data=Movies,x='Critical_Ratings',y='Audience_Ratings',fit_reg=False)

# %%
vis1= sns.lmplot(data=Movies,x='Critical_Ratings',y='Audience_Ratings',fit_reg=False,hue='Genre')

# %%
vis1= sns.lmplot(data=Movies,x='Critical_Ratings',y='Audience_Ratings',\
                 fit_reg=False,hue='Genre', height=10 ,aspect=1)

# %%
k1= sns.kdeplot(data=Movies,x="Critical_Ratings",y='Audience_Ratings')

# %%
k1= sns.kdeplot(data=Movies,x="Critical_Ratings",y='Audience_Ratings',shade= True,shade_lowest= False,cmap='Reds')

# %%
k1= sns.kdeplot(data=Movies,x="Critical_Ratings",y='Audience_Ratings',shade_lowest= False,cmap='Greens_r')

# %%
sns.set_style('dark')
k2= sns.kdeplot(data=Movies, x='Budget', y= 'Audience_Ratings',shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k2= sns.kdeplot(data=Movies, x='Budget', y= 'Audience_Ratings')

# %%
k3= sns.kdeplot(data=Movies, x='Budget', y= 'Critical_Ratings')

# %%
# subplots

f,ax= plt.subplots(1,2, figsize= (12,6))

# %%
f,ax = plt.subplots(3,3,figsize=(12,6))

# %%
f, axes= plt.subplots(1,2,figsize=(12,6))
k2= sns.kdeplot(data=Movies, x='Budget', y= 'Audience_Ratings',ax=axes[0])
k3= sns.kdeplot(data=Movies, x='Budget', y= 'Critical_Ratings',ax=axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='Budget', ylabel='Audience_Ratings'>,
#        <Axes: xlabel='Budget', ylabel='Critical_Ratings'>], dtype=object)

# %%
# boxplot

w= sns.boxplot(data= Movies,x='Genre',y='Critical_Ratings',hue='Genre')

# %%
w= sns.violinplot(data= Movies,x='Genre',y='Critical_Ratings',hue = 'Genre')

# %%
w= sns.boxplot(data= Movies[Movies.Genre== 'Action'],x='Year',y='Critical_Ratings')

# %%
w= sns.violinplot(data= Movies[Movies.Genre== 'Action'],x='Year',y='Critical_Ratings')

# %%
g = sns.FacetGrid(Movies,row='Genre',col='Year',hue="Genre")

# %%
plt.scatter(Movies.Critical_Ratings,Movies.Audience_Ratings)

# %%
g = sns.FacetGrid(Movies,row='Genre',col='Year',hue="Genre")
g=g.map(plt.scatter,'Critical_Ratings','Audience_Ratings')

# %%
g1= sns.FacetGrid(Movies,row='Genre',col='Year',hue='Genre')
g1=g1.map(plt.hist,'Budget')

# %%
g1= sns.FacetGrid(Movies,row='Genre',col='Year',hue='Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g1=g1.map(plt.scatter,'Critical_Ratings','Audience_Ratings',**kws)

# %%
# using subplots for different plots
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data= Movies,x= 'Budget',y= 'Audience_Ratings',ax=axes[0,0])
k2 = sns.kdeplot(data= Movies,x= 'Budget',y= 'Critical_Ratings',ax = axes[0,1])

k1.set(xlim=(-50,250))
k2.set(xlim=(-50,250))

z = sns.violinplot(data=Movies[Movies.Genre=='Drama'], x='Year', y = 'Critical_Ratings', ax=axes[1,0])

k4 = sns.kdeplot(data= Movies,x= 'Audience_Ratings',y= 'Critical_Ratings',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4 = sns.kdeplot(data= Movies,x= 'Audience_Ratings',y= 'Critical_Ratings',cmap='Reds',ax=axes[1,1])

plt.show()

# %%
sns.set_style('darkgrid', {'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data= Movies,x= 'Budget',y= 'Audience_Ratings', shade = True, shade_lowest=True,cmap = 'Blues_r',ax=axes[0,0])
k1b = sns.kdeplot(data= Movies,x= 'Budget',y= 'Audience_Ratings',cmap='cool',ax= axes[0,0])

k2 = sns.kdeplot(data= Movies,x= 'Budget',y= 'Critical_Ratings', shade = True, shade_lowest=True,cmap = 'inferno',ax = axes[0,1])
k2b= sns.kdeplot(data= Movies,x= 'Budget',y= 'Critical_Ratings',cmap='cool',ax=axes[0,1])

k1.set(xlim=(-50,250))
k1b.set(xlim=(-50,250))
k2.set(xlim=(-50,250))
k2b.set(xlim=(-50,250))


z = sns.violinplot(data=Movies[Movies.Genre=='Drama'], x='Year', y = 'Critical_Ratings', ax=axes[1,0])


k4 = sns.kdeplot(data= Movies,x= 'Audience_Ratings',y= 'Critical_Ratings',shade = True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])
k4b = sns.kdeplot(data= Movies,x= 'Audience_Ratings',y= 'Critical_Ratings',cmap='gist_gray_r',ax=axes[1,1])

plt.show()
