# %% [markdown]
# ## Image

# %%
import numpy as np
import matplotlib.pyplot  as plt

# %%
from PIL import Image  # python image library

# %%
img= Image.open(r"D:\1.  Data science\Python\16th, 17th june- python\python.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1068x670>
